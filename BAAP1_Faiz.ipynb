# %% [markdown]
# # Faiz Khan  - 2021600034 - CSE AIML

# %%
import pandas as pd

# %% [markdown]
# **DataFrame**
#
# Pandas DataFrame is two-dimensional size-mutable, potentially heterogeneous tabular data structure with labeled axes (rows and columns). A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. Pandas DataFrame consists of three principal components, the data, rows, and columns.

# %% [markdown]
# ##**Part 1**  -  Reading csv file using DataFrame

# %%
df = pd.read_csv('startup_funding.csv')
df.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %% [markdown]
# ##**Part 2**  -  Export DataFrame to Excel file
#
# In this example, startup_funding.xlsx is the target file name. The index parameter, when set to False, prevents the index column from being exported.

# %% [markdown]
# The to_excel() function provides various optional parameters for customizing the exported file, including handling missing values, formatting column names, and more.
#
# - na_rep: replace missing values.
#
# - header: customize the column names.
#
# - index_label: optional column label for the index column.

# %%
df.to_excel('startup_funding.xlsx', index=False, na_rep='N/A')
#here all missing values will be put as N/A

# %% [markdown]
# ##**Part 3**  -  Load JSON into dataframe
#
#
# **Note:**
# Here, pd.json_normalize(df2['state']) is used to flatten the nested 'state' column, and then the resulting DataFrame is processed similarly

# %%
df2 = pd.read_json('states.json')
df_result2 = pd.json_normalize(df2['states'])
df_result2.head()
# Out:
#   state.state_id                 state.state_name
# 0             AN  Andaman and Nicobar Island (UT)
# 1             AP                   Andhra Pradesh
# 2             AR                Arunachal Pradesh
# 3             AS                            Assam
# 4             BR                            Bihar

# %%
n = len(pd.unique(df['InvestmentnType']))
print("No.of.unique values :", n)
# Out:
# No.of.unique values : 56

# %% [markdown]
# ## **Part 4**  -   BONUS: Analysis
#
# **- Question1)
# Top 5 largest investments**

# %% [markdown]
# Renaming columns to simpler names for access -

# %%
df.rename(columns={
    'Date dd/mm/yyyy': 'date',
    'Startup Name': 'startup',
    'Industry Vertical': 'vertical',
    'SubVertical': 'subvertical',
    'City  Location': 'city',
    'Investors Name': 'investors',
    'InvestmentnType': 'round',
    'Amount in USD': 'amount'
}, inplace=True)

df.head()
# Out:
#    Sr No        date                       startup             vertical  \
# 0      1  09/01/2020                        BYJU’S               E-Tech
# 1      2  13/01/2020                        Shuttl       Transportation
# 2      3  09/01/2020                     Mamaearth           E-commerce
# 3      4  02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5  02/01/2020                        Fashor  Fashion and Apparel
#
#                              subvertical       city  \
# 0                             E-learning  Bengaluru
# 1              App based shuttle service    Gurgaon
# 2  Retailer of baby and toddler products  Bengaluru
# 3                      Online Investment  New Delhi
# 4            Embroiled Clothes For Women     Mumbai
#
#                    investors                 round        amount Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %% [markdown]
# **Processing amount**
#
# Dealing with empty, unknown, undisclosed and arbitrary values
# Converting to float for analysis

# %%
def clean_string(x):
    return str(x).replace("\\xc2\\xa0","").replace("\\\\xc2\\\\xa0", "")

for col in ["date", "startup", "vertical", "subvertical", "city", "investors", "round", "amount"]:
    df[col] = df[col].apply(lambda x: clean_string(x))

# %%
df.amount = df.amount.str.replace(',','')
df.head()
# Out:
#    Sr No        date                       startup             vertical  \
# 0      1  09/01/2020                        BYJU’S               E-Tech
# 1      2  13/01/2020                        Shuttl       Transportation
# 2      3  09/01/2020                     Mamaearth           E-commerce
# 3      4  02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5  02/01/2020                        Fashor  Fashion and Apparel
#
#                              subvertical       city  \
# 0                             E-learning  Bengaluru
# 1              App based shuttle service    Gurgaon
# 2  Retailer of baby and toddler products  Bengaluru
# 3                      Online Investment  New Delhi
# 4            Embroiled Clothes For Women     Mumbai
#
#                    investors                 round     amount Remarks
# 0    Tiger Global Management  Private Equity Round  200000000     NaN
# 1  Susquehanna Growth Equity              Series C    8048394     NaN
# ...

# %%
df.amount = df.amount.str.replace('undisclosed', '0')
df.amount = df.amount.str.replace('unknown', '0')
df.amount = df.amount.str.replace('+', '')
df.amount = df.amount.str.replace('N/A', '0')
df.amount = df.amount.str.replace('n/a', '0')
df.amount = df.amount.str.replace('', '0')
# Out:
# <ipython-input-30-f41101fd69c2>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.amount = df.amount.str.replace('+', '')

# %% [markdown]
# ### One final check to make sure if any non-digit it can be ignored

# %%
def clean_amount(x):
    if str(x).isdigit():
        return x
    else:
        return 0


df.amount = df.amount.apply(lambda x: float(clean_amount(x)))

# %% [markdown]
# **Checking 5 biggest investments We can see that Flipkart and Paytm top the list with the largest investments...** (However Rapido is incorrect)

# %%
sorted_df = df.sort_values(by='amount', ascending=False)
sorted_df.head()
# Out:
#      Sr No        date           startup        vertical  \
# 60      61  27/08/2019  Rapido Bike Taxi  Transportation
# 651    652  11/08/2017          Flipkart       eCommerce
# 966    967  21/03/2017          Flipkart       eCommerce
# 830    831  18/05/2017             Paytm       ECommerce
# 31      32  25/11/2019             Paytm         FinTech
#
#                             subvertical       city  \
# 60                            Bike Taxi  Bengaluru
# 651                  Online Marketplace  Bangalore
# 966               ECommerce Marketplace  Bangalore
# 830  Mobile Wallet & ECommerce platform  Bangalore
# 31                        Mobile Wallet      Noida
#
#                              investors           round        amount Remarks
# 60                  Westbridge Capital        Series B  3.090000e+19     NaN
# 651                           Softbank  Private Equity  2.050000e+19     NaN
# 966  Microsoft, eBay, Tencent Holdings  Private Equity  1.040000e+19     NaN
# ...

# %% [markdown]
# Rapido amount is given incorrect: 3.9 billion INR and not USD. So we convert accordingly to --> USD

# %%
df.loc[df['startup']=='Rapido Bike Taxi', 'amount'] = 50000000
sorted_df = df.sort_values(by='amount', ascending=False)
sorted_df.head()
# Out:
#       Sr No        date       startup            vertical  \
# 651     652  11/08/2017      Flipkart           eCommerce
# 830     831  18/05/2017         Paytm           ECommerce
# 966     967  21/03/2017      Flipkart           eCommerce
# 31       32  25/11/2019         Paytm             FinTech
# 2648   2649  28/07/2015  Flipkart.com  Online Marketplace
#
#                              subvertical       city  \
# 651                   Online Marketplace  Bangalore
# 830   Mobile Wallet & ECommerce platform  Bangalore
# 966                ECommerce Marketplace  Bangalore
# 31                         Mobile Wallet      Noida
# 2648                                 nan  Bangalore
#
#                                      investors           round        amount  \
# 651                                   Softbank  Private Equity  2.050000e+19
# 830                             SoftBank Group  Private Equity  1.040000e+19
# ...
